# %%
# %run train.py --num_units=32 --dataset=dstc4 --patience=0
# Out:
# batch_size = 16
# dataset = dstc4
# early_stop = True
# input_file = seq.in
# intent_file = label
# intent_file_one = label_one
# intent_file_two = label_two
# layer_size = 32
# max_epochs = 20
# model_path = ./model
# model_type = full
# patience = 0
# slot_file = seq.out
# test_data_path = test
# train_data_path = train
# valid_data_path = valid
# vocab_path = ./vocab
#
# use own dataset:  dstc4
# WARNING:tensorflow:From C:\Users\김원규\Desktop\11_lab_과제\SlotGated-SLU-master\train.py:91: BasicLSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is deprecated, please use tf.nn.rnn_cell.LSTMCell, which supports all the feature this cell currently has. Please replace the existing code with tf.nn.rnn_cell.LSTMCell(name='basic_lstm_cell').
# layer_size:  32
#
# ...
